# %%
import pandas as pd

# %%
path_dataset = 'datasets/argentina_sueldos.csv'
df = pd.read_csv(path_dataset, sep= ';', engine='python')
df = df.dropna()

# %%
df.dtypes
# Out:
# Me identifico                                                     object
# Tengo                                                              int64
# Años de experiencia                                                int64
# Años en la empresa actual                                          int64
# Años en el puesto actual                                           int64
# ¿Gente a cargo?                                                    int64
# Nivel de estudios alcanzado                                       object
# Estado                                                            object
# ¿Contribuís a proyectos open source?                              object
# ¿Programás como hobbie?                                           object
# Lenguajes de programación                                         object
# Bases de datos                                                    object
# ¿Qué SO usás en tu laptop/PC para trabajar?                       object
# ...

# %%
df["Lenguajes de programación"]=[str(c).split(',') for c in df["Lenguajes de programación"]]

# %%
df["Lenguajes de programación"]
# Out:
# 28      [CSS,  HTML,  Java,  Javascript,  SQL,  TypeSc...
# 30                                  [Bash/Shell,  Python]
# 32                             [Go,  Groovy,  Java,  SQL]
# 35            [.NET,  C#,  CSS,  HTML,  Javascript,  SQL]
# 36      [.NET,  ActionScript,  C#,  CSS,  HTML,  Javas...
#                               ...
# 2745                            [HTML,  Javascript,  PHP]
# 2746                     [CSS,  HTML,  Java,  Ruby,  SQL]
# 2748               [C#,  Javascript,  Python,  SQL,  VBA]
# 2749                                       [PHP,  Python]
# 2750    [Bash/Shell,  CSS,  HTML,  Javascript,  Python...
# Name: Lenguajes de programación, Length: 1752, dtype: object

# %%
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(35, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
